# %% [markdown]
# # CROPSENSE PROJECT

# %% [markdown]
# ## 1. Librairies
#
# This project needs libraries in order to work.
# You will may need to install them by using `pip install tifffile imagecodecs numpy pandas pymongo matplotlib scipy opencv-python --user` on your Terminal (type cmd on Windows)

# %%
import os
import shutil
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tifffile as tiff
from datetime import datetime
from pymongo import MongoClient
import gridfs
from scipy.interpolate import make_interp_spline

# %% [markdown]
# ## 2. Setup and annex functions

# %% [markdown]
# ### 2.1 Setup

# %%
PATH_INBOX = "C:/CROPSENSE/INBOX"          # Inbox folder (Camera software output)
PATH_DATA_ROOT = "C:/CROPSENSE/CROPSENSE_DATA" # Hierarchical final storage
PATH_EXPORT = "C:/CROPSENSE/EXPORTED_FROM_DB" # Path where exported data from database will be stored
CSV_LOG_PATH = "./experience_log.csv"      # Ground Truth tracking file

# MongoDB Connection (Auto-switch Local/Server)
URIS_TO_TRY = ['localhost', '172.20.10.8'] # Add your server IPs here
DB_NAME = 'cropsense_db'
COLLECTION_NAME = 'capture_events'

# Define SILIOS Wavelengths mapping for easier access
SILIOS_WAVELENGTHS = {
    0: "410nm", 1: "463nm", 2: "500nm", 3: "557nm", 4: "605nm",
    5: "666nm", 6: "693nm", 7: "756nm", 8: "807nm", 9: "869nm"
}

# Define the demosaicing pattern (Same as in your pipeline)
TOUCAN_PATTERN = {
    0: [(0,3), (2,1)], 1: [(0,1), (2,3)], 2: [(2,0)], 3: [(0,0), (2,2)],
    4: [(1,2)], 5: [(3,0)], 6: [(1,0)], 7: [(1,3), (3,1)],
    8: [(1,1), (3,3)], 9: [(3,2)]
}

# SILIOS TOUCAN Demosaicing Matrix (Fixed Pattern)
# Source: TOUCAN Matrix Filter arrangement V1.0
TOUCAN_PATTERN = {
    0: [(0,3), (2,1)], 1: [(0,1), (2,3)], 2: [(2,0)], 3: [(0,0), (2,2)],
    4: [(1,2)], 5: [(3,0)], 6: [(1,0)], 7: [(1,3), (3,1)],
    8: [(1,1), (3,3)], 9: [(3,2)]
}

# %% [markdown]
# ### 2.2 Functions

# %% [markdown]
# #### 2.2.1 `get_mongo_client()`
# This utility function implements a robust failover connection strategy for the database. It iterates through a predefined list of URI strings (typically `localhost` and the remote server IP) and attempts to establish a connection with a short timeout. It validates the connection by requesting server information; if successful, it returns the active MongoDB client object, ensuring the pipeline can operate seamlessly in both standalone and networked environments.

# %%
def get_mongo_client():
    """Attempts to connect to MongoDB using the provided list of URIs."""
    for uri in URIS_TO_TRY:
        print(f"Attempt to connect to MongoDB on {uri}")
        try:
            client = MongoClient(uri, 27017, serverSelectionTimeoutMS=2000)
            client.server_info() # Force connection check
            print(f"✅ Connected to MongoDB on {uri}")
            return client
        except:
            continue
    print("❌ Critical Error: No database accessible.")
    return None

# %% [markdown]
# #### 2.2.2 `parse_colorshades_manifest(txt_filepath)`
# Designed to extract technical and scientific metadata, this function parses the auxiliary text files (`.txt`) generated by the Color Shades acquisition software. It reads the file content line by line to identify key parameters such as the camera serial number (Camera SN) and exposure time. Crucially, it also retrieves the calibrated filter wavelengths and channel normalization coefficients, ensuring that the subsequent spectral reconstruction adheres strictly to the specific radiometric calibration of the sensor.

# %%
def parse_colorshades_manifest(txt_filepath):
    """
    Parses the .txt manifest generated by Color Shades to extract technical metadata
    including real wavelengths and normalization coefficients.
    """
    meta = {
        "camera_sn": "Unknown", 
        "exposure": 1.0, 
        "wavelengths": [],    
        "coefficients": []    
    }
    
    if not os.path.exists(txt_filepath):
        return meta

    try:
        with open(txt_filepath, 'r') as f:
            content = f.readlines()
            
        for line in content:
            # Serial Number
            if "Camera SN" in line:
                meta["camera_sn"] = line.split(":")[-1].strip()
            
            # Exposure (remove " ms" unit)
            if "Exposure" in line:
                val = line.split(":")[-1].strip().replace(" ms", "")
                try: meta["exposure"] = float(val)
                except: pass
                
            # Real Wavelengths (e.g. 411, 463...)
            if "Filter's centering (nm)" in line:
                raw_vals = line.split(":")[-1].strip().split()
                meta["wavelengths"] = [int(x) for x in raw_vals]
                
            # Channel Coefficients
            if "Coefficients channel normalizer" in line:
                raw_vals = line.split(":")[-1].strip().split()
                meta["coefficients"] = [float(x) for x in raw_vals]
                
    except Exception as e:
        print(f"⚠️ Error reading manifest {os.path.basename(txt_filepath)}: {e}")
        
    return meta

# %% [markdown]
# #### 2.2.3 `organize_incoming_files()`
# This function acts as the ingestion engine of the pipeline. It scans the "`INBOX`" directory for raw files and uses Regular Expressions (Regex) to parse filenames, extracting the Plant ID and determining the sensor type (Spectral or Thermal). Based on the file creation timestamp and the extracted identifiers, it dynamically creates a hierarchical directory structure (`Date`/`PlantID`/`SensorType`) and moves the files from the temporary inbox to this permanent storage, effectively automating the data sorting process and filtering out irrelevant files like screenshots.

# %%
def organize_incoming_files():
    """
    Sorts files from INBOX into the hierarchy: DATA_ROOT / Date / Plant_ID / Sensor_Type
    Implements specific logic for prefixes 'Spectral', 'Multispectral', 'Thermal'.
    """
    print("\n--- 1. Sorting incoming files (INBOX) ---")
    if not os.path.exists(PATH_INBOX): 
        print(f"⚠️ Inbox directory not found: {PATH_INBOX}")
        return

    count = 0
    # Reserved keywords that cannot be Plant IDs
    RESERVED_KEYWORDS = ["SPECTRAL", "MULTISPECTRAL", "THERMAL"]

    for filename in os.listdir(PATH_INBOX):
        file_path = os.path.join(PATH_INBOX, filename)
        if os.path.isdir(file_path): continue

        # Init variables
        plant_id = "Unassigned"
        sensor_type = "Unclassified"
        filename_clean = filename.strip()
        
        # --- RULE 1: EXPLICIT PREFIX DETECTION ---
        # Check if file starts with specific keywords followed by a separator (e.g., "_")
        # Regex looks for: (Spectral|Thermal) _ (PotentialID) _ (Rest)
        match_explicit = re.match(r"^(Spectral|Multispectral|Thermal)_([a-zA-Z0-9]+)_(.*)", filename_clean, re.IGNORECASE)
        
        if match_explicit:
            type_str = match_explicit.group(1).upper()
            candidate_id = match_explicit.group(2)
            
            # 1.1 Determine Sensor Type
            if "THERMAL" in type_str:
                sensor_type = "Thermal"
            else:
                sensor_type = "Spectral"
                
            # 1.2 Validate Plant ID
            # Rule: Must not be a reserved word AND must start with a letter
            if candidate_id.upper() not in RESERVED_KEYWORDS and candidate_id[0].isalpha():
                plant_id = candidate_id
            else:
                plant_id = "Unassigned"
                
        else:
            # --- RULE 2: FALLBACK PATTERN DETECTION ---
            # If no explicit prefix, try to guess based on file structure
            
            # Case A: Thermal (Starts with digits like "00-10-12...")
            # Also checks for thermal keywords if the pattern matches
            if re.match(r"^(\d{2}-\d{2}-\d{2}-\d{3})", filename_clean):
                sensor_type = "Thermal"
                print(f"   [Ingestion] Pattern Detection used: Thermal Digit Pattern detected for {filename}")
                plant_id = "Unassigned" # Thermal files usually don't have the ID in the name here
                 
            # Case B: Spectral (Contains Date_Time pattern OR ends with specific extensions)
            elif re.search(r"_\d{8}_\d{6}_", filename_clean) or filename_clean.lower().endswith(('_raw.tiff', '.txt')):
                sensor_type = "Spectral"
            print(f"   [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for {filename}")
                
                # Try to extract Plant ID from the start of the file
                # Split by first underscore
            parts = filename_clean.split('_')
            if len(parts) > 1:
                    candidate = parts[0]
                    # Same validation rules
                    if candidate.upper() not in RESERVED_KEYWORDS and candidate[0].isalpha():
                        plant_id = candidate
                    else:
                        plant_id = "Unassigned"

        print(f"   [Ingestion] File: {filename} -> Detected Type: {sensor_type}, Plant: {plant_id}")

        # --- PROCESSING & MOVING ---
        
        # Filter: Delete Thermal Screenshots
        if sensor_type == "Thermal" and "screenshot" in filename_clean.lower():
            try:
                os.remove(file_path)
                print(f"🗑️ Deleted screenshot: {filename}")
            except Exception as e:
                print(f"⚠️ Could not delete {filename}: {e}")
            continue
            
        # Move Valid Files
        if sensor_type != "Unclassified":
            try:
                timestamp = os.path.getmtime(file_path)
                date_folder = datetime.fromtimestamp(timestamp).strftime('%Y-%m-%d')
                
                # Target: DATA / Date / PlantID / SensorType
                target_dir = os.path.join(PATH_DATA_ROOT, date_folder, plant_id, sensor_type)
                os.makedirs(target_dir, exist_ok=True)
                
                target_path = os.path.join(target_dir, filename)
                if not os.path.exists(target_path):
                    shutil.move(file_path, target_path)
                    count += 1
                    print(f"📦 Moved: {filename} -> {plant_id}/{sensor_type}")
                else:
                    print(f"ℹ️ Skipped (Duplicate): {filename}")
            except Exception as e:
                print(f"❌ Error moving {filename}: {e}")
        else:
            print(f"⚠️ Skipped Unclassified file: {filename}")

    print(f"   -> {count} files successfully organized.")

# %% [markdown]
# #### 2.2.4 `process_spectral_image(filepath, manifest_meta)`
# This function executes the core signal processing for multispectral data by reading raw `TIFF` images and applying a demosaicing algorithm based on the SILIOS TOUCAN 4x4 filter pattern to reconstruct a 10-band spectral cube. Crucially, it applies radiometric correction by normalizing the raw pixel intensity of each band using specific coefficients retrieved from the sensor's manifest file. Finally, it extracts features by generating an intensity histogram (`256 bins`) for each corrected wavelength (dynamically named based on the manifest, e.g., 411nm), packaging these analytics alongside the correction factors into a dictionary for database storage.

# %%
def process_spectral_image(filepath, manifest_meta):
    img_data = tiff.imread(filepath)
    h, w = img_data.shape
    print(f"   [Processing] Loaded Raw TIFF. Dimensions: {w}x{h} pixels.")
    new_h, new_w = h // 4, w // 4
    
    # Retrieve dynamic info from the text file
    # If the text file was missing, use default values
    real_wavelengths = manifest_meta.get("wavelengths")
    if not real_wavelengths or len(real_wavelengths) != 10:
        real_wavelengths = [411, 463, 500, 557, 606, 667, 694, 756, 808, 870] # Fallback
        
    coeffs = manifest_meta.get("coefficients")
    if not coeffs or len(coeffs) != 10:
        coeffs = [1.0] * 10 # No correction if file is missing
        
    cube = np.zeros((10, new_h, new_w), dtype=np.float32)
    analytics = {}
    print(f"   [Processing] Applied Normalization Coefficients: {coeffs}")
    
    for band_idx, coords in TOUCAN_PATTERN.items():
        # 1. Reconstruction (Demosaicing)
        stack = [img_data[r::4, c::4][:new_h, :new_w] for r, c in coords]
        raw_band = np.mean(stack, axis=0)
        
        # 2. Radiometric Correction (Applying the coefficient)
        # This is the crucial step: normalizing the intensity
        corrected_band = raw_band * coeffs[band_idx]
        
        # Store in the cube
        cube[band_idx] = corrected_band

        print(f"   [Processing] Signal Stats -> Min: {np.min(cube):.2f}, Max: {np.max(cube):.2f}, Mean: {np.mean(cube):.2f}")
        
        # 3. Histogram Calculation on the CORRECTED band
        # Use the real name (e.g., "411nm" not "410nm")
        band_name = f"{real_wavelengths[band_idx]}nm"
        
        # Round for the histogram because coefficients create decimals
        hist, _ = np.histogram(corrected_band.astype(np.uint16), bins=256)
        
        analytics[band_name] = {
            "histogram": hist.tolist(),
            "correction_factor": coeffs[band_idx] # Store the factor used
        }
        
    return {
        "camera_model": "SILIOS TOUCAN",
        "camera_sn": manifest_meta.get("camera_sn", "Unknown"),
        "exposure_ms": manifest_meta.get("exposure"),
        "analytics": analytics
    }

# %% [markdown]
# #### 2.2.5 `find_thermal_cluster(spectral_path, tolerance=120)`
# To achieve sensor fusion, this function implements a temporal reconciliation algorithm. Using the timestamp of a processed spectral image as a reference anchor, it recursively scans the daily directory structure to locate 'Thermal' subfolders. It identifies files created within a defined tolerance window (e.g., ±300 seconds) and aggregates the four specific output files generated by the Workswell camera—Visual RGB, Radiometric JPEG, Raw Thermal TIFF, and CWSI TIFF—into a unified logical cluster, thereby linking asynchronous captures into a single event.

# %%
def find_thermal_cluster(spectral_path, plant_id, tolerance=300):
    """
    Finds the cluster of 4 Workswell thermal files corresponding to the spectral image timestamp, according to their ID.
    Searches in all 'Thermal' subfolders for the same date.
    """
    matches = {}
    spec_time = datetime.fromtimestamp(os.path.getmtime(spectral_path))
    
    # 1. Construct the specific target path
    # Structure: DATA / Date / PlantID / Spectral  --> We want DATA / Date / PlantID / Thermal
    spectral_folder = os.path.dirname(spectral_path)    # .../PlantID/Spectral
    plant_root = os.path.dirname(spectral_folder)       # .../PlantID
    target_thermal_dir = os.path.join(plant_root, "Thermal")
    
    # 2. Immediate exit if the folder doesn't exist for THIS plant
    if not os.path.exists(target_thermal_dir): 
        return matches

    # 3. Scan ONLY this specific directory
    for f in os.listdir(target_thermal_dir):
        f_path = os.path.join(target_thermal_dir, f)
        
        # Skip directories
        if os.path.isdir(f_path): continue
        
        # Check time
        therm_time = datetime.fromtimestamp(os.path.getmtime(f_path))
        
        if abs((spec_time - therm_time).total_seconds()) <= tolerance:
            if "visible" in f: matches["visual_rgb"] = f_path
            elif "radiometric" in f: matches["radiometric_jpg"] = f_path
            elif "thermo" in f: matches["raw_thermal_tiff"] = f_path
            elif "cwsi" in f: matches["cwsi_tiff"] = f_path
                    
    return matches

# %% [markdown]
# #### 2.2.6 `save_gridfs_file(fs, file_id, folder, default_name)`
# An helper function to save a single file from GridFS.
# It is used for example on `batch_export_all()`

# %%
def save_gridfs_file(fs, file_id, folder, default_name):
    """Helper function to save a single file from GridFS"""
    try:
        grid_out = fs.get(file_id)
        
        # Use the real filename if available in GridFS metadata
        if grid_out.filename:
            final_name = grid_out.filename
        else:
            final_name = default_name
            
        output_path = os.path.join(folder, final_name)
        
        # Skip if already exists
        if os.path.exists(output_path):
            return

        with open(output_path, 'wb') as f:
            f.write(grid_out.read())
            
    except Exception as e:
        print(f"      -> Failed to save file {file_id}: {e}")

# %% [markdown]
# #### 2.2.7 `process_independent_thermal(date_folder_path, db_collection, fs)`
#
# This function acts as a comprehensive safety mechanism designed to ingest thermal datasets that were not temporally synchronized with spectral images during the main pipeline execution. By performing a secondary scan of the Thermal directories, it systematically identifies and groups isolated Workswell camera outputs—combining the Visible, Radiometric, Raw TIFF, and CWSI files into coherent acquisition events based on their shared timestamps. To maintain database integrity, the function performs a rigorous deduplication check against MongoDB, ensuring that only truly new data is processed. These independent events are then archived with a specific schema where the multispectral field is explicitly set to null, allowing researchers to easily query and distinguish standalone thermal experiments from multi-sensor data within the global dataset.

# %%
def process_independent_thermal(date_folder_path, db_collection, fs):
    """
    Scans for thermal files that were NOT linked to a spectral event and uploads them.
    No specific tag is added to the database; the spectral field will simply be Null.
    
    Args:
        date_folder_path (str): Path to the Date folder (e.g., .../2025-12-10/)
        db_collection: MongoDB collection object
        fs: GridFS object
    """
    print(f"\n🔄 [Independent Thermal] Scanning for standalone thermal data in {os.path.basename(date_folder_path)}...")
    
    count_new = 0
    
    # 1. Walk through all folders in this Date
    for root, dirs, files in os.walk(date_folder_path):
        folder_name = os.path.basename(root)
        
        # We only care about "Thermal" folders
        if folder_name != "Thermal":
            continue
            
        # Deduce Plant ID from parent folder (e.g. .../P01/Thermal -> P01)
        plant_id = os.path.basename(os.path.dirname(root))
        
        # 2. Group files by 'Shot' (Timestamp prefix)
        # Workswell files look like: "14-20-00-123-thermo.tiff"
        shots = {}
        
        for f in files:
            # Simple regex to capture the HH-MM-SS-mmm prefix
            match = re.match(r"^(\d{2}-\d{2}-\d{2}-\d{3})", f)
            if match:
                prefix = match.group(1)
                if prefix not in shots: shots[prefix] = {}
                
                full_path = os.path.join(root, f)
                
                # Assign type
                if "visible" in f: shots[prefix]["visual_rgb"] = full_path
                elif "radiometric" in f: shots[prefix]["radiometric_jpg"] = full_path
                elif "thermo" in f: shots[prefix]["raw_thermal_tiff"] = full_path
                elif "cwsi" in f: shots[prefix]["cwsi_tiff"] = full_path

        # 3. Process each shot
        for prefix, file_dict in shots.items():
            
            # CHECK: Does this thermal data already exist in DB?
            # We look for the filename in the 'sensor_thermal' section to avoid duplicates.
            if "raw_thermal_tiff" in file_dict:
                ref_filename = os.path.basename(file_dict["raw_thermal_tiff"])
                exists = db_collection.find_one({"sensor_thermal.original_filename": ref_filename})
                
                if exists:
                    # Already processed (either via Spectral Fusion or previously imported) -> Skip
                    continue
            
            # 4. If not in DB, it's a new Independent Event
            stored_files_ids = {}
            
            # Upload files to GridFS
            for f_type, f_path in file_dict.items():
                try:
                    with open(f_path, 'rb') as f_in:
                        # We upload to GridFS
                        fid = fs.put(f_in, filename=os.path.basename(f_path), content_type="image/tiff")
                        stored_files_ids[f_type] = fid
                except Exception as e:
                    print(f"   ⚠️ Error uploading {f_path}: {e}")

            # Create Database Document
            try:
                # Reconstruct timestamp from filename (HH-MM-SS-mmm) and Folder Date
                time_parts = prefix.split("-") # ['14', '20', '00', '123']
                date_str = os.path.basename(date_folder_path) # '2025-12-10'
                
                # Format: YYYY-MM-DD HH:MM:SS
                timestamp_str = f"{date_str} {time_parts[0]}:{time_parts[1]}:{time_parts[2]}"
                
                event_doc = {
                    "context": {
                        "plant_id": plant_id,
                        "timestamp": timestamp_str
                        # No 'mode' tag added here, keeping it clean.
                    },
                    "sensor_multispectral": None, # Explicitly Empty
                    "sensor_thermal": {
                        "camera_model": "WORKSWELL WIRIS AGRO R",
                        "original_filename": os.path.basename(file_dict.get("raw_thermal_tiff", "unknown")),
                        "files": stored_files_ids,
                        "detected_count": len(stored_files_ids)
                    }
                }
                
                db_collection.insert_one(event_doc)
                print(f"   ✅ Saved Thermal Event (No Spectral): {plant_id} @ {time_parts[0]}:{time_parts[1]}")
                count_new += 1
                
            except Exception as e:
                print(f"   ❌ Error saving doc: {e}")

    print(f"   -> Added {count_new} new independent thermal events.")

# %% [markdown]
# ## 3. Main functions

# %% [markdown]
# #### 3.1 `run_pipeline()`
# This is the main orchestrator function that executes the full ETL (Extract, Transform, Load) workflow. It sequentially triggers the file organization, establishes the database connection, and iterates through the structured dataset. For every valid spectral image found, it coordinates the processing (via `process_spectral_image`), the fusion (via `find_thermal_cluster`), and the construction of the final JSON document. Finally, it handles the upload of binary files to MongoDB's GridFS and the insertion of the structured document into the collection.
#
# #### ⚠️ RUN IT ONLY WHEN YOUR DATA IS CLEAN ⚠️

# %%
def run_pipeline():
    # A. Ingestion (Organization)
    organize_incoming_files()
    
    # B. Database Connection
    client = get_mongo_client()
    if not client: return
    
    db = client[DB_NAME]
    fs = gridfs.GridFS(db)
    coll = db[COLLECTION_NAME]

    print("\n--- 2. Scientific Processing ---")
    
    # Iterate through organized data
    for root, dirs, files in os.walk(PATH_DATA_ROOT):
        # We drive the process using Spectral folders
        if os.path.basename(root) != "Spectral": continue
        
        # 1. Search for Manifest (.txt)
        manifest_meta = {}
        txt_files = [f for f in files if f.endswith(".txt")]
        if txt_files:
            manifest_meta = parse_colorshades_manifest(os.path.join(root, txt_files[0]))
            print(f"📄 [Manifest] {txt_files[0]} Loaded metadata -> SN: {manifest_meta.get('camera_sn')}, Exp: {manifest_meta.get('exposure')}ms")

        # 2. Process Images
        for file in files:
            if not file.endswith("_raw.tiff"): continue
            
            # Anti-Duplicate Check
            if coll.count_documents({"sensor_multispectral.filename": file}) > 0:
                continue

            print(f"⚙️ Processing: {file}")
            filepath = os.path.join(root, file)
            
            try:
                # Identification from folder structure
                plant_id = os.path.basename(os.path.dirname(root)) 
                timestamp = datetime.fromtimestamp(os.path.getmtime(filepath))
                
                # Processing (Spectral)
                # Note: Uses 'manifest_meta' to apply coefficients if implemented
                spec_data = process_spectral_image(filepath, manifest_meta)
                
                # Fusion (Thermal)
                thermal_files = find_thermal_cluster(filepath, plant_id=plant_id)
                
                # --- AJOUT DU PRINT DE DÉBOGAGE ICI ---
                if thermal_files:
                    # On récupère juste le nom des fichiers pour que ce soit lisible
                    t_names = [os.path.basename(p) for p in thermal_files.values()]
                    print(f"   🔗 [Fusion] Thermal files associated : {t_names}")
                else:
                    print("   ⚠️ [Fusion] Aucun fichier thermique correspondant trouvé (hors délai).")
                    
                print(f"   [Fusion] Thermal files found: {list(thermal_files.keys())}")
                thermal_data = {
                    "camera_model": "WORKSWELL WIRIS AGRO R",
                    "files": {},
                    "detected_count": len(thermal_files)
                }

                # Auto-Tagging Control Samples
                tags = []
                if plant_id in ['P02', 'P50', 'Plant_2', 'Plant_50']: 
                    tags.append("control_sample")

                print(f"   [Metadata] Assigned Tags: {tags}")

                # Document Assembly
                doc = {
                    "context": {
                        "plant_id": plant_id,
                        "timestamp": timestamp,
                        "session": "Morning" if timestamp.hour < 13 else "Evening",
                        "environment": "Laboratory"
                    },
                    "sensor_multispectral": {
                        "filename": file,
                        "meta": spec_data,
                        "raw_file_id": None
                    },
                    "sensor_thermal": thermal_data,
                    "tags": tags
                }
                # C. Upload to Database
                print(f"   [Storage] Uploading Spectral binary file ({os.path.getsize(filepath)} bytes) to GridFS...")
                
                # 1. Upload Spectral Image
                with open(filepath, 'rb') as f:
                    doc['sensor_multispectral']['raw_file_id'] = fs.put(f, filename=file)
                
                # 2. Upload Thermal Files (if any)
                for key, t_path in thermal_files.items():
                    with open(t_path, 'rb') as f:
                        file_id = fs.put(f, filename=os.path.basename(t_path))
                        doc['sensor_thermal']['files'][key] = file_id

                # 3. Save Metadata Document
                coll.insert_one(doc)
                print(f"✅ [Success] Event recorded for {plant_id} at {timestamp}. (DB ID: {doc['_id']})")

            except Exception as e:
                print(f"   ❌ Error processing {file}: {e}")
    print("\n--- 3. Independent Thermal Scan ---")
    for date_folder in os.listdir(PATH_DATA_ROOT):
        full_date_path = os.path.join(PATH_DATA_ROOT, date_folder)
        if os.path.isdir(full_date_path):
            process_independent_thermal(full_date_path, coll, fs)
            
    print("\n✅ Pipeline execution complete.")

# %% [markdown]
# ### 3.2 `rename_batch_prefix(folder_path, old_prefix, new_prefix)`
# This function batch renames all files in a folder that start with an old prefix, replacing that start with a new prefix.
# Useful when the files saved are prenamed by the camera or the sofware output, and you want to change the name of all the file you just used, or you want to solve a mistake.

# %%
def rename_batch_prefix(folder_path, old_prefix, new_prefix):
    """
    Batch renames all files in a folder that start with 'old_prefix',
    replacing that start with 'new_prefix'.
    
    Example: 
    rename_batch_prefix("C:/INBOX", "hbda", "PLANT1")
    will transform "hbda.0001.tiff" into "PLANT1.0001.tiff"
    """
    
    # 1. Folder verification
    if not os.path.exists(folder_path):
        print(f"❌ Folder does not exist: {folder_path}")
        return

    print(f"🔄 Renaming in progress in {folder_path}...")
    print(f"   Replacing '{old_prefix}' with '{new_prefix}'")
    
    count = 0
    errors = 0

    # 2. Iterate through files
    for filename in os.listdir(folder_path):
        # Process only files starting with the old prefix
        if filename.startswith(old_prefix):
            
            # Construct the new filename
            # Cut the "old_prefix" part and paste "new_prefix" at the start
            suffix = filename[len(old_prefix):] # The rest of the name (e.g., ".0001.tiff")
            new_filename = new_prefix + suffix
            
            old_path = os.path.join(folder_path, filename)
            new_path = os.path.join(folder_path, new_filename)
            
            try:
                # Safety check: do not overwrite if the file already exists
                if os.path.exists(new_path):
                    print(f"⚠️ Skipped (Already exists): {new_filename}")
                    errors += 1
                    continue
                
                # Actual renaming
                os.rename(old_path, new_path)
                print(f"✅ {filename} -> {new_filename}")
                count += 1
                
            except Exception as e:
                print(f"❌ Error on {filename}: {e}")
                errors += 1

    print(f"\n--- Finished: {count} files renamed ({errors} errors) ---")

# %% [markdown]
# ### 3.3 `export_file_from_db(output_folder, plant_id, sensor_type, thermal_file_type, mongo_uri, db_name)`
# This function retrieves a multispectral file from a MongoDB database and saves it to a specified output folder on the local disk. By default, it fetches the most recent image recorded in the database; however, if a specific `plant_id` is provided, the search is filtered to retrieve the last image associated with that plant. The connection is established using the provided mongo_uri (defaulting to '`localhost`') and db_name. If `sensor_type` equals to `spectral`, `thermal_file_type` has no use. However, if `sensor_type` equals to `thermal`, `thermal_file_type` allows to choose between `visual_rgb`, `radiometric.jpg`, `raw_thermal_tiff`, and `cwsi_tiff`. Upon completion, the function returns the absolute path of the saved file, or `None` if the operation fails.

# %%
def export_file_from_db(output_folder, plant_id=None, sensor_type='spectral', thermal_file_type='radiometric_jpg', mongo_uri='localhost', db_name='cropsense_db'):
    """
    Retrieves a file (Spectral OR Thermal) from MongoDB and saves it to disk.
    
    Parameters:
    - output_folder (str): Destination folder.
    - plant_id (str, optional): ID of the plant (e.g., "P01"). If None, takes the latest event.
    - sensor_type (str): 'spectral' OR 'thermal'.
    - thermal_file_type (str): Only if sensor_type='thermal'. 
                               Options: 'visual_rgb', 'radiometric_jpg', 'raw_thermal_tiff', 'cwsi_tiff'.
    """
    
    # 1. Connect to DB
    try:
        client = MongoClient(mongo_uri, 27017, serverSelectionTimeoutMS=2000)
        db = client[db_name]
        fs = gridfs.GridFS(db)
        coll = db['capture_events']
        client.server_info()
    except Exception as e:
        print(f"❌ Connection Error: {e}")
        return None

    # 2. Find Event
    query = {}
    if plant_id:
        query["context.plant_id"] = plant_id
        print(f"🔍 Searching last event for plant: {plant_id}...")
    else:
        print("🔍 Searching for the very last event recorded...")

    event = coll.find_one(query, sort=[("context.timestamp", -1)])
    if not event:
        print("⚠️ No event found.")
        return None

    # 3. Identify File ID based on request
    file_id = None
    original_filename = "unknown_file"

    try:
        if sensor_type == 'spectral':
            # Get the main TIFF file
            data_node = event.get('sensor_multispectral', {})
            file_id = data_node.get('raw_file_id')
            original_filename = data_node.get('filename', 'spectral.tif')
            
        elif sensor_type == 'thermal':
            # Get one of the 4 thermal files
            files_node = event.get('sensor_thermal', {}).get('files', {})
            
            # Map the user request to the database keys
            # Database keys are: visual_rgb_id, radiometric_jpg_id, etc.
            # We construct the key dynamically:
            db_key = f"{thermal_file_type}_id" # e.g. "radiometric_jpg_id"
            
            file_id = files_node.get(db_key)
            
            # We try to reconstruct a name (since it wasn't explicitly stored in the simplified node)
            # But GridFS knows the name! We will get it later.
            original_filename = f"thermal_{thermal_file_type}.img" 

        # 4. Download and Save
        if not file_id:
            print(f"⚠️ No file found for sensor '{sensor_type}' (Type: {thermal_file_type}) in this event.")
            return None

        if not os.path.exists(output_folder):
            os.makedirs(output_folder)

        # Retrieve from GridFS
        grid_out = fs.get(file_id)
        data = grid_out.read()
        
        # Use the real filename stored in GridFS if possible
        if grid_out.filename:
            original_filename = grid_out.filename
            
        output_path = os.path.join(output_folder, original_filename)
        
        with open(output_path, 'wb') as f:
            f.write(data)
            
        print(f"✅ File saved: {output_path}")
        print(f"   (Source: {sensor_type} | Date: {event['context']['timestamp']})")
        return output_path

    except Exception as e:
        print(f"❌ Error during extraction: {e}")
        return None

# %% [markdown]
# ### 3.4 `batch_export_all()`
# This function is a mass extraction tool designed to reconstruct your entire physical dataset from the MongoDB database. It begins by establishing a connection to the server and retrieving all recorded event documents, then iterates through each entry to extract contextual metadata (plant identifier and date).
#
# Using this information, it dynamically recreates a structured folder hierarchy on your hard drive (e.g., `EXPORT/P01/2025-11-25`) and queries the GridFS system to download and write the original binary files (spectral TIFF and thermal images) back into their respective folders, thereby ensuring a comprehensive backup or data transfer to a standard file system.

# %%
def batch_export_all():
    print(f"🚀 Starting Batch Export to: {EXPORT_ROOT}")
    
    # 1. Connection
    try:
        client = MongoClient(MONGO_URI, 27017, serverSelectionTimeoutMS=2000)
        db = client[DB_NAME]
        fs = gridfs.GridFS(db)
        coll = db['capture_events']
        client.server_info()
    except Exception as e:
        print(f"❌ Connection Error: {e}")
        return

    # 2. Get ALL events
    # You can add a filter here, e.g., {"context.plant_id": "P01"}
    cursor = coll.find({}) 
    total_docs = coll.count_documents({})
    
    print(f"📦 Found {total_docs} events to process...")

    count = 0
    for doc in cursor:
        try:
            # 3. Context Info
            context = doc.get('context', {})
            plant_id = context.get('plant_id', 'Unknown')
            # Safe timestamp handling
            ts = context.get('timestamp')
            if isinstance(ts, str): # If stored as string
                date_str = ts[:10] # YYYY-MM-DD
            elif isinstance(ts, datetime): # If stored as Date object
                date_str = ts.strftime('%Y-%m-%d')
            else:
                date_str = "NoDate"

            # 4. Create Target Folder
            # Structure: EXPORT / PlantID / Date
            target_folder = os.path.join(EXPORT_ROOT, plant_id, date_str)
            if not os.path.exists(target_folder):
                os.makedirs(target_folder)

            # 5. Export Spectral File
            spec_node = doc.get('sensor_multispectral', {})
            spec_id = spec_node.get('raw_file_id')
            if spec_id:
                filename = spec_node.get('filename', f"spectral_{plant_id}.tif")
                save_gridfs_file(fs, spec_id, target_folder, filename)

            # 6. Export Thermal Files
            therm_node = doc.get('sensor_thermal', {}).get('files', {})
            for file_type, file_id in therm_node.items():
                # file_type is like "radiometric_jpg_id"
                # We construct a name if the original isn't stored, or get it from GridFS
                filename = f"thermal_{file_type}.img" 
                save_gridfs_file(fs, file_id, target_folder, filename)

            count += 1
            print(f"   [{count}/{total_docs}] Processed {plant_id} ({date_str})")

        except Exception as e:
            print(f"   ❌ Error processing doc {doc.get('_id')}: {e}")

    print("\n✅ Batch Export Completed.")

# %% [markdown]
# ### 3.5 `export_recent_files(output_folder, limit, plant_id, sensor_type, thermal_file_type, mongo_uri, db_name)`
#
# This function retrieves the most recent batch of images from the database and saves them to the specified `output_folder`. The number of retrieved files is controlled by the limit parameter (defaulting to 5), and the query can be optionally filtered by a specific `plant_id` or left open to include all plants. The function requires defining the `sensor_type` as either '`spectral`' or '`thermal`'; if '`thermal`' is selected, the specific file format (such as '`visual_rgb`' or '`radiometric_jpg`') must be designated using the `thermal_file_type` argument.

# %%
def export_recent_files(output_folder, limit=5, plant_id=None, sensor_type='spectral', thermal_file_type='radiometric_jpg', mongo_uri='localhost', db_name='cropsense_db'):
    """
    Retrieves the last 'n' images recorded in the database.
    
    Parameters:
    - output_folder (str): Folder where files will be saved.
    - limit (int): Number of files to retrieve (default 5).
    - plant_id (str, optional): Filter by plant (e.g., "P01"). If None, takes all plants.
    - sensor_type (str): 'spectral' OR 'thermal'.
    - thermal_file_type (str): If thermal, which file? ('visual_rgb', 'radiometric_jpg', etc.)
    """
    
    # 1. Connection
    try:
        client = MongoClient(mongo_uri, 27017, serverSelectionTimeoutMS=2000)
        db = client[db_name]
        fs = gridfs.GridFS(db)
        coll = db['capture_events']
        client.server_info()
    except Exception as e:
        print(f"❌ Connection Error: {e}")
        return

    # 2. Query Configuration
    query = {}
    if plant_id:
        query["context.plant_id"] = plant_id
        print(f"🔍 Searching for the last {limit} images for plant: {plant_id}...")
    else:
        print(f"🔍 Searching for the last {limit} images (all plants)...")

    # 3. Retrieve cursor (Sorted by date DESC)
    # .limit(limit) restricts the number of results
    cursor = coll.find(query).sort("context.timestamp", -1).limit(limit)
    
    count = 0
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 4. Loop through results
    for event in cursor:
        try:
            # -- Same logic as the single function to find the ID --
            file_id = None
            filename_prefix = ""

            if sensor_type == 'spectral':
                data_node = event.get('sensor_multispectral', {})
                file_id = data_node.get('raw_file_id')
                # We add the timestamp to the name to avoid duplicates if filenames are identical
                ts_str = event['context']['timestamp'].strftime("%H%M%S")
                original_name = data_node.get('filename', 'spec.tif')
                
            elif sensor_type == 'thermal':
                files_node = event.get('sensor_thermal', {}).get('files', {})
                db_key = f"{thermal_file_type}_id"
                file_id = files_node.get(db_key)
                ts_str = event['context']['timestamp'].strftime("%H%M%S")
                original_name = f"thermal_{thermal_file_type}.img"

            # -- Download --
            if file_id:
                grid_out = fs.get(file_id)
                # If GridFS has the real name, use it, otherwise use the constructed one
                final_name = grid_out.filename if grid_out.filename else original_name
                
                # Security: To avoid overwriting, we can prefix with the plant ID
                p_id = event['context']['plant_id']
                save_name = f"{p_id}_{final_name}"
                
                output_path = os.path.join(output_folder, save_name)
                
                with open(output_path, 'wb') as f:
                    f.write(grid_out.read())
                
                print(f"   ✅ [{count+1}/{limit}] Saved: {save_name}")
                count += 1
            else:
                print(f"   ⚠️ Event found but no file for this sensor (Plant: {event['context']['plant_id']})")

        except Exception as e:
            print(f"   ❌ Error on a file: {e}")

    print(f"🚀 Completed. {count} files exported to {output_folder}")

# %% [markdown]
# ### 3.6 `check_database_integrity(plant_id_to_check, mongo_uri, db_name)`

# %%
def check_database_integrity(plant_id_to_check, mongo_uri='localhost', db_name='cropsense_db'):
    """
    Diagnose function to verify if files for a specific plant are correctly stored in GridFS.
    
    Args:
        plant_id_to_check (str): The Plant ID to look for (e.g., "FirstTests", "PO1").
        mongo_uri (str): Address of the MongoDB server.
    """
    print(f"\n🔍 --- DIAGNOSIS FOR PLANT: {plant_id_to_check} ---")
    
    # 1. Connection
    try:
        client = MongoClient(mongo_uri, 27017, serverSelectionTimeoutMS=2000)
        db = client[db_name]
        fs = gridfs.GridFS(db)
        coll = db['capture_events']
        client.server_info() # Check connection
    except Exception as e:
        print(f"❌ Connection Failed: {e}")
        return

    # 2. General Stats
    total_files = db['fs.files'].count_documents({})
    print(f"📦 Total binary files in GridFS (All plants): {total_files}")

    # 3. Find the Document
    # We look for the most recent event for this plant
    event = coll.find_one({"context.plant_id": plant_id_to_check}, sort=[("context.timestamp", -1)])

    if not event:
        print(f"❌ No metadata document found for plant '{plant_id_to_check}'.")
        print("   -> Check if the Plant ID is correct (Case sensitive!).")
        return

    print(f"✅ Metadata document found (Date: {event['context']['timestamp']})")

    # 4. Check Spectral File
    print("\n   [Spectral Sensor]")
    spec_id = event.get('sensor_multispectral', {}).get('raw_file_id')
    if spec_id:
        if fs.exists(spec_id):
            file_meta = fs.get(spec_id)
            print(f"     ✅ RAW TIFF exists (Size: {file_meta.length / 1024 / 1024:.2f} MB)")
        else:
            print(f"     ❌ ERROR: File ID exists in document but file is missing in GridFS!")
    else:
        print("     ⚠️ No Spectral file linked.")

    # 5. Check Thermal Files
    print("\n   [Thermal Sensor]")
    thermal_files = event.get('sensor_thermal', {}).get('files', {})
    
    if not thermal_files:
        print("     ⚠️ No Thermal files linked (Empty list).")
    else:
        for file_type, file_id in thermal_files.items():
            if fs.exists(file_id):
                file_meta = fs.get(file_id)
                print(f"     ✅ {file_type}: OK (Size: {file_meta.length / 1024:.2f} KB)")
            else:
                print(f"     ❌ {file_type}: Missing body in GridFS (ID: {file_id})")

# %% [markdown]
# ### 3.7 `show_spectral_channel(filepath, channel_index, wavelength)`
#
# This visualization utility is designed to permit granular inspection of the multispectral data. It provides a flexible interface allowing users to query a specific spectral band either by its index (0-9) or its physical wavelength (e.g., '756nm'). The function automatically adapts to the input file format: for pre-processed spectral stacks (3D arrays), it extracts the corresponding slice, while for raw sensor mosaics (2D arrays), it executes an on-the-fly demosaicing process to reconstruct the specific band image based on the sensor's filter matrix. The resulting radiometric data is then rendered as a high-contrast color-mapped heatmap using Matplotlib, facilitating the visual assessment of pixel intensity distributions across the leaf surface.

# %%
def show_spectral_channel(filepath, channel_index=None, wavelength=None, interpolation='bicubic'):
    """
    Displays a specific channel from a SILIOS multispectral TIFF file.
    
    Parameters:
    - filepath (str): Path to the .tiff file (Raw Mosaic or Stack).
    - channel_index (int): Index of the band (0 to 9, or 0 to 125).
    - wavelength (str/int): Wavelength to find (e.g., 557 or "557nm"). 
                            Overrides channel_index if provided.
    """
    
# 1. Resolve Channel Index from Wavelength
    if not os.path.exists(filepath):
        print(f"❌ File not found: {filepath}")
        return

    # 1. Charger l'image D'ABORD pour connaître sa structure
    try:
        img_data = tiff.imread(filepath)
    except Exception as e:
        print(f"❌ Error reading file: {e}")
        return

    is_125_bands = (img_data.ndim == 3 and img_data.shape[2] == 125)

    # 2. Résoudre le channel_index si une longueur d'onde est fournie
    if wavelength is not None:
        target_wl = float(str(wavelength).replace("nm", "").strip())
        
        if is_125_bands:
            # Formule inversée : Index = (Wavelength - 450) / (500 / 124)
            step = 500 / 124
            calculated_idx = int(round((target_wl - 450) / step))
            channel_index = max(0, min(124, calculated_idx)) # Garder entre 0 et 124
            print(f"🔍 Wavelength {target_wl}nm correspond to channel index {channel_index}")
        else:
            # Logique d'origine pour SILIOS (10 bandes)
            found = False
            for idx, name in SILIOS_WAVELENGTHS.items():
                if str(int(target_wl)) in name:
                    channel_index = idx
                    found = True
                    break
            if not found:
                print(f"❌ Wavelength '{wavelength}' not found in SILIOS.")
                return

    if channel_index is None:
        print("❌ Invalid channel index.")
        return

    # 3. Extraction de l'image
    band_image = None
    if is_125_bands:
        band_image = img_data[:, :, channel_index]
        mode = "External Stack (125 Bands)"
        # Calcul de la longueur d'onde exacte pour l'affichage
        wl_display = f"{450 + channel_index * (500 / 124):.1f} nm"
        
    elif img_data.ndim == 3 and img_data.shape[0] < img_data.shape[1]:
        band_image = img_data[channel_index]
        mode = "Processed Stack (Silios)"
        wl_display = SILIOS_WAVELENGTHS.get(channel_index, f"Canal {channel_index}")
        
    elif img_data.ndim == 2:
        if channel_index not in TOUCAN_PATTERN: return
        h, w = img_data.shape
        new_h, new_w = h // 4, w // 4
        stack = [img_data[r::4, c::4][:new_h, :new_w] for r, c in TOUCAN_PATTERN[channel_index]]
        band_image = np.mean(stack, axis=0)
        mode = "Raw Mosaic (Silios)"
        wl_display = SILIOS_WAVELENGTHS.get(channel_index, f"Canal {channel_index}")

    # 4. Affichage
    plt.figure(figsize=(8, 8))
    plt.title(f"Spectral Image: {wl_display}\nMode: {mode}")
    img_plot = plt.imshow(band_image, cmap='inferno', interpolation=interpolation) # Lissage ajouté ici !
    plt.colorbar(img_plot, label="Pixel Intensity")
    plt.axis('off') 
    plt.show()

# %% [markdown]
# ### 3.8 `show_thermal_image(filepath)`
# This visualization utility is specifically designed to render single-channel radiometric data produced by the Workswell WIRIS camera. Unlike standard image viewers which often display raw 16-bit thermal data as undefined black pixels, this function maps the raw scalar values (Temperature or Crop Water Stress Index) to a perceptually uniform color palette (e.g., 'Magma' for temperature, 'Red-Yellow-Green' for `CWSI`). Beyond simple visualization, it computes and prints key descriptive statistics—minimum, maximum, and mean values—providing immediate quantitative insight into the thermal dynamics of the plant sample directly from the raw file.

# %%
def show_thermal_image(filepath):
    """
    Displays a thermal image (Raw TIFF or CWSI) with a color scale.
    Also prints statistics (Min, Max, Mean) of the temperature/index.
    
    Parameters:
    - filepath (str): Path to the .tiff file (e.g., '..._thermo.tiff' or '..._cwsi.tiff')
    """
    
    if not os.path.exists(filepath):
        print(f"❌ File not found: {filepath}")
        return

    try:
        # 1. Read Image
        # For thermal, it's a simple 2D image (1 channel), not a cube.
        img_data = tiff.imread(filepath)
        
        # 2. Detect Type (Temperature or CWSI)
        filename = os.path.basename(filepath).lower()
        
        if "cwsi" in filename:
            # CWSI is an index between 0 and 1 (or 0-100%)
            label_unit = "CWSI Index (Water Stress)"
            cmap_choice = "RdYlGn_r" # Red = High Stress, Green = Healthy
        else:
            # Raw Thermo
            label_unit = "Raw Value (Temperature)"
            cmap_choice = "magma" # Black/Purple = Cold, Orange/Yellow = Hot
            
        # 3. Calculate Statistics
        val_min = np.min(img_data)
        val_max = np.max(img_data)
        val_avg = np.mean(img_data)
        
        print(f"📊 Statistics for {filename}:")
        print(f"   🔹 Min: {val_min:.2f}")
        print(f"   🔸 Max: {val_max:.2f}")
        print(f"   sz Mean: {val_avg:.2f}")

        # 4. Graphical Display
        plt.figure(figsize=(10, 8))
        plt.title(f"Thermal Analysis: {filename}")
        
        # Display with false colors
        img_plot = plt.imshow(img_data, cmap=cmap_choice)
        
        # Side Colorbar
        cbar = plt.colorbar(img_plot)
        cbar.set_label(label_unit, rotation=270, labelpad=15)
        
        plt.axis('off')
        plt.show()

    except Exception as e:
        print(f"❌ Error during display: {e}")

# %% [markdown]
# #### 3.9 `plot_image_histogram(filepath, band_index, bins, log_scale)`
#
# This visualization utility is designed for the granular inspection of radiometric distribution within a single data channel. It features a polymorphic interface that automatically adapts to the input file type: for 3D multispectral cubes, it extracts and analyzes a specific wavelength band defined by the user (e.g., Band 7 - Red Edge), whereas for 2D thermal matrices, it processes the entire array. The function renders a frequency histogram of pixel intensities and overlays key statistical indicators—specifically the mean and median values—allowing the operator to rapidly assess exposure quality and detect potential sensor saturation or underexposure in specific spectral or thermal regions.

# %%
def plot_image_histogram(filepath, band_index=None, bins=100, log_scale=False):
    """
    Displays the pixel intensity distribution histogram for a given image.
    Handles both Spectral images (selectable band) and Thermal images.
    
    Parameters:
    - filepath (str): Path to the .tiff file.
    - band_index (int, optional): Band index (0-9) for spectral files. Ignored for thermal.
    - bins (int): Number of bars in the histogram (default 100).
    - log_scale (bool): If True, uses a logarithmic scale (useful if background dominates).
    """
    
    
    if not os.path.exists(filepath):
        print(f"❌ File not found: {filepath}")
        return

    try:
        img_data = tiff.imread(filepath)
        data_to_plot = None
        title_suffix = ""
        color = 'gray'

        # --- CASE 1: PROCESSED 3D CUBE (Bands, H, W) ---
        if img_data.ndim == 3 and img_data.shape[0] < img_data.shape[1]:
            if band_index is None: band_index = 0
            if band_index >= img_data.shape[0]:
                print(f"❌ Invalid band index ({band_index}).")
                return

            data_to_plot = img_data[band_index].flatten()
            wl = SILIOS_WAVELENGTHS.get(band_index, f"Band {band_index}")
            title_suffix = f"- Spectral {wl} (Processed)"
            color = 'purple'

        # --- CASE 1.5: EXTERNAL DATASET (H, W, Bands) ---
        elif img_data.ndim == 3 and img_data.shape[2] > 1:
            if band_index is None: band_index = 0
            if band_index >= img_data.shape[2]:
                print(f"❌ Invalid band index ({band_index}).")
                return
            
            data_to_plot = img_data[:, :, band_index].flatten()
            wl = SILIOS_WAVELENGTHS.get(band_index, f"Band {band_index}")
            title_suffix = f"- Spectral {wl} (External Data)"
            color = 'purple'

        # --- CASE 2: RAW 2D MOSAIC OR THERMAL ---
        elif img_data.ndim == 2:
            if "thermo" in filepath.lower() or "cwsi" in filepath.lower():
                data_to_plot = img_data.flatten()
                title_suffix = "- Thermal Data"
                color = 'orange'
            elif band_index is not None:
                if band_index not in TOUCAN_PATTERN:
                    print("❌ Error: Invalid band index for RAW Mosaic")
                    return
                r_off = band_index // 4
                c_off = band_index % 4
                data_to_plot = img_data[r_off::4, c_off::4].flatten()
                wl = SILIOS_WAVELENGTHS.get(band_index, f"Band {band_index}")
                title_suffix = f"- Spectral {wl} (Extracted from RAW)"
                color = 'blue'
            else:
                data_to_plot = img_data.flatten()
                title_suffix = "- Full Raw Mosaic (Mixed)"
                color = 'black'
        else:
            print(f"❌ Unrecognized format with shape: {img_data.shape}")
            return

        plt.figure(figsize=(10, 6))
        mean_val = np.mean(data_to_plot)
        median_val = np.median(data_to_plot)
        
        plt.hist(data_to_plot, bins=bins, color=color, alpha=0.7, log=log_scale, edgecolor='black', linewidth=0.5)
        plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_val:.2f}')
        plt.axvline(median_val, color='yellow', linestyle='dotted', linewidth=1.5, label=f'Median: {median_val:.2f}')
        
        plt.title(f"Histogram: {os.path.basename(filepath)}\n{title_suffix}")
        plt.xlabel("Pixel Intensity")
        plt.ylabel("Frequency")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()

    except Exception as e:
        print(f"❌ Error calculating histogram: {e}")

# %% [markdown]
# #### 3.10 `plot_full_spectral_histogram(filepath, mode, bins, log_scale)`
#
# Developed for a holistic assessment of multispectral data quality, this function processes the entire 10-band spectral cube simultaneously. It operates in two distinct modes to suit different analytical needs: the 'Overlay' mode plots ten distinct distribution curves on a single set of axes, enabling immediate comparative analysis of sensor response across different wavelengths (essential for identifying dead bands or inconsistent gain settings). Alternatively, the 'Global' mode aggregates pixel data from all channels into a single cumulative histogram, providing a macro-view of the image's overall dynamic range usage. This tool is critical for validating that the camera integration settings are appropriate for the current lighting conditions before further processing.

# %%
def plot_full_spectral_histogram(filepath, mode='overlay', bins=100, log_scale=False):
    """
    Plots the histogram for the ENTIRE multispectral image.
    
    Parameters:
    - filepath (str): Path to the 10-band spectral TIFF.
    - mode (str): 
        'overlay' = Plots 10 separate lines (one per band) on the same graph.
        'global'  = Aggregates all pixels into one single histogram.
    - bins (int): Number of bins.
    - log_scale (bool): Logarithmic Y-axis.
    """
    
    if not os.path.exists(filepath):
        print(f"❌ File not found: {filepath}")
        return

    try:
        img_data = tiff.imread(filepath)
        plt.figure(figsize=(12, 7))
        title_mode = ""
        
        # --- CASE 1: SPECTRAL CUBE (Both Internal & External) ---
        if img_data.ndim == 3:
            is_external = img_data.shape[2] > 1 and img_data.shape[2] > img_data.shape[0]
            num_bands = img_data.shape[2] if is_external else img_data.shape[0]
            
            if mode == 'overlay':
                print(f"📊 Plotting overlay of {num_bands} spectral bands...")
                cmap = plt.get_cmap('tab20')
                for i in range(num_bands):
                    wl = SILIOS_WAVELENGTHS.get(i, f"Band {i}")
                    band_pixels = img_data[:, :, i].flatten() if is_external else img_data[i].flatten()
                    
                    plt.hist(band_pixels, bins=bins, histtype='step', linewidth=1.5,
                             label=f"{wl}", color=cmap(i % 20), log=log_scale)
                
                # Limiter la légende si le nombre de bandes est immense (ex: 125)
                if num_bands <= 20:
                    plt.legend(loc='upper right', fontsize='small', ncol=2)
                title_mode = "Per-Band Analysis (Processed Cube)"
                
            else:
                print("📊 Plotting global distribution (3D Cube)...")
                plt.hist(img_data.flatten(), bins=bins, color='gray', alpha=0.8, log=log_scale, label="All Bands")
                title_mode = "Global Distribution (Processed Cube)"

        # --- CASE 2: RAW MOSAIC or THERMAL (2D) ---
        elif img_data.ndim == 2:
            print("📊 Plotting Global Raw Histogram.")
            plt.hist(img_data.flatten(), bins=bins, color='black', alpha=0.7, log=log_scale, label="Raw Pixels")
            max_val = np.max(img_data)
            plt.axvline(max_val, color='red', linestyle='--', label=f'Max Detected: {max_val}')
            title_mode = "Raw Sensor Distribution (Global)"
            plt.legend()
        else:
            print(f"❌ Error: Unrecognized image shape {img_data.shape}")
            return

        plt.title(f"{title_mode}\n{os.path.basename(filepath)}")
        plt.xlabel("Pixel Intensity")
        plt.ylabel("Frequency (Log)" if log_scale else "Frequency")
        plt.grid(True, alpha=0.3)
        plt.show()

    except Exception as e:
        print(f"❌ Error calculating histogram: {e}")

# %% [markdown]
# #### 3.11 `plot_spectral_profile(filepath)`
#
# This function generates a Spectral Signature curve, effectively summarizing the average reflectance characteristics of the imaged subject across the ten discrete channels of the Silios CMS4 sensor. Unlike a standard frequency histogram, this tool maps specific wavelengths (in nanometers) on the X-axis against the mean pixel intensity on the Y-axis, allowing for a direct visualization of the spectral response profile. The function features an adaptive data processing logic that accommodates both raw 2D sensor mosaics—performing real-time pixel extraction to isolate channel data—and fully reconstructed 3D spectral cubes. This visualization is critical for identifying dominant spectral features, such as the characteristic "Green Peak" (557nm) or the sharp rise in the "Red Edge" (756nm+) typical of healthy vegetation biomass.

# %%
def plot_spectral_profile(filepath, smooth=True):
    """
    Plots the Spectral Signature with optional smoothing (Interpolation).
    
    Parameters:
    - filepath: Path to image
    - smooth: If True, draws a curved line. If False, draws straight lines.
    """
    
   
    if not os.path.exists(filepath):
        return

    try:
        img_data = tiff.imread(filepath)
        y_real = []
        x_real = []
        
        is_125_bands = (img_data.ndim == 3 and img_data.shape[2] == 125)
        is_external = img_data.ndim == 3 and img_data.shape[2] > 1 and img_data.shape[2] > img_data.shape[0]
        num_bands = img_data.shape[2] if is_external else (img_data.shape[0] if img_data.ndim == 3 else 10)

        # 1. Extraction des intensités (Y) et calcul des longueurs d'onde (X)
        for i in range(num_bands):
            if is_external:
                y_real.append(np.mean(img_data[:, :, i]))
            elif img_data.ndim == 3:
                y_real.append(np.mean(img_data[i]))
            else: # Raw mosaic 2D
                r_off, c_off = i // 4, i % 4
                y_real.append(np.mean(img_data[r_off::4, c_off::4]))
            
            # Calcul de l'axe X
            if is_125_bands:
                x_real.append(450 + i * (500 / 124))
            else:
                wl_str = SILIOS_WAVELENGTHS.get(i, str(400 + i*5)).replace("nm", "")
                x_real.append(float(wl_str))

        y_real = np.array(y_real)
        x_real = np.array(x_real)

        # 2. Lissage (Smoothing)
        x_smooth, y_smooth = x_real, y_real
        if smooth and len(x_real) > 3:
            x_smooth = np.linspace(x_real.min(), x_real.max(), 300)
            from scipy.interpolate import make_interp_spline
            spline = make_interp_spline(x_real, y_real, k=3) 
            y_smooth = spline(x_smooth)

        # 3. Affichage
        plt.figure(figsize=(10, 6))
        plt.plot(x_smooth, y_smooth, color='teal', linewidth=2.5, label='Interpolated Profile')
        # Pour 125 points, on réduit la taille des marqueurs pour que ce soit lisible
        marker_size = 15 if is_125_bands else 50
        plt.scatter(x_real, y_real, color='red', s=marker_size, zorder=5, label='Measured Bands')
        
        plt.title(f"Spectral Signature\n{os.path.basename(filepath)}")
        plt.xlabel("Wavelength (nm)")
        plt.ylabel("Mean Intensity")
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.5)
        plt.show()

    except Exception as e:
        print(f"❌ Error: {e}")

# %% [markdown]
# #### 3.12 `export_histogram_to_csv(filepath, output_csv, analysis_type, bins)`
#
# This data extraction utility bridges the gap between the Python processing pipeline and external statistical tools (such as Excel, R, or JMP). Instead of generating a visual plot, it computes the numerical histogram data—specifically the bin edges and pixel counts—and serializes the results into a structured CSV format. For multispectral files in histogram mode, it generates a multi-column dataset containing the distribution frequency for each of the 10 separate bands; for thermal files, it outputs a single distribution profile. In profile mode, it generates a dataset containing all the wavelength frequency. This function enables researchers to perform quantitative comparative studies of exposure distributions across large datasets without needing to reopen the raw TIFF files.

# %%
def export_analysis_to_csv(filepath, output_csv="data_export.csv", analysis_type="profile", bins=256):
    """
    Master function to export analysis data to CSV for Excel/Stats.
    
    Parameters:
    - filepath: Path to the TIFF file.
    - output_csv: Filename for the saved CSV.
    - analysis_type: 
        * 'profile'   -> Exports Mean Intensity vs Wavelength (The Curve).
        * 'histogram' -> Exports Pixel Counts vs Intensity for all bands (The Distribution).
    - bins: Number of bins (only used if type is 'histogram').
    """
    if not os.path.exists(filepath):
        return

    img_data = tiff.imread(filepath)
    data_dict = {} 
    
    try:
        is_125_bands = (img_data.ndim == 3 and img_data.shape[2] == 125)
        is_external = img_data.ndim == 3 and img_data.shape[2] > 1 and img_data.shape[2] > img_data.shape[0]
        num_bands = img_data.shape[2] if is_external else (img_data.shape[0] if img_data.ndim == 3 else 10)

        if analysis_type == "profile":
            wavelengths = []
            intensities = []

            for i in range(num_bands):
                # Remplissage X (Wavelengths)
                if is_125_bands:
                    wavelengths.append(round(450 + i * (500 / 124), 2))
                else:
                    wavelengths.append(int(SILIOS_WAVELENGTHS.get(i, f"{400+i*5}nm").replace("nm", "")))
                
                # Remplissage Y (Intensities)
                if is_external:
                    intensities.append(np.mean(img_data[:, :, i]))
                elif img_data.ndim == 3:
                    intensities.append(np.mean(img_data[i]))
                else:
                    r_off, c_off = i // 4, i % 4
                    intensities.append(np.mean(img_data[r_off::4, c_off::4]))
            
            data_dict["Wavelength_nm"] = wavelengths
            data_dict["Mean_Intensity"] = intensities
            
        elif analysis_type == "histogram":
            max_val = np.max(img_data)
            bin_edges = np.linspace(0, max_val, bins + 1)
            data_dict["Bin_Start_Value"] = bin_edges[:-1]
            
            for i in range(num_bands):
                if is_125_bands:
                    band_name = f"{450 + i * (500 / 124):.1f}nm"
                else:
                    band_name = SILIOS_WAVELENGTHS.get(i, f"Band_{i}")
                
                if is_external:
                    pixels = img_data[:, :, i].flatten()
                elif img_data.ndim == 3:
                    pixels = img_data[i].flatten()
                else:
                    r_off, c_off = i // 4, i % 4
                    pixels = img_data[r_off::4, c_off::4].flatten()
                
                counts, _ = np.histogram(pixels, bins=bin_edges)
                data_dict[f"Count_{band_name}"] = counts

        df = pd.DataFrame(data_dict)
        df.to_csv(output_csv, index=False)
        print(f"✅ Success! Data saved to: {output_csv}")
        return df

    except Exception as e:
        print(f"❌ Error during export: {e}")

# %% [markdown]
# ## 4 Here is the code !

# %%
#To classify everything, order in local, then sending it on the database
# ⚠️ RUN IT ONLY WHEN YOUR DATA IS CLEAN ⚠️

run_pipeline()
# Out:
# --- 1. Sorting incoming files (INBOX) ---
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_1.tif
#    [Ingestion] File: Other_hyper_1.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_1.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_10.tif
#    [Ingestion] File: Other_hyper_10.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_10.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_100.tif
#    [Ingestion] File: Other_hyper_100.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_100.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_101.tif
#    [Ingestion] File: Other_hyper_101.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_101.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_102.tif
#    [Ingestion] File: Other_hyper_102.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_102.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_103.tif
#    [Ingestion] File: Other_hyper_103.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_103.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_104.tif
#    [Ingestion] File: Other_hyper_104.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_104.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_105.tif
#    [Ingestion] File: Other_hyper_105.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_105.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_106.tif
#    [Ingestion] File: Other_hyper_106.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_106.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_107.tif
#    [Ingestion] File: Other_hyper_107.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_107.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_108.tif
#    [Ingestion] File: Other_hyper_108.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_108.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_109.tif
#    [Ingestion] File: Other_hyper_109.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_109.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_11.tif
#    [Ingestion] File: Other_hyper_11.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_11.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_110.tif
#    [Ingestion] File: Other_hyper_110.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_110.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_111.tif
#    [Ingestion] File: Other_hyper_111.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_111.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_112.tif
#    [Ingestion] File: Other_hyper_112.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_112.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_113.tif
#    [Ingestion] File: Other_hyper_113.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_113.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_114.tif
#    [Ingestion] File: Other_hyper_114.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_114.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_115.tif
#    [Ingestion] File: Other_hyper_115.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_115.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_116.tif
#    [Ingestion] File: Other_hyper_116.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_116.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_117.tif
#    [Ingestion] File: Other_hyper_117.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_117.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_118.tif
#    [Ingestion] File: Other_hyper_118.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_118.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_119.tif
#    [Ingestion] File: Other_hyper_119.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_119.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_12.tif
#    [Ingestion] File: Other_hyper_12.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_12.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_120.tif
#    [Ingestion] File: Other_hyper_120.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_120.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_121.tif
#    [Ingestion] File: Other_hyper_121.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_121.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_122.tif
#    [Ingestion] File: Other_hyper_122.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_122.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_123.tif
#    [Ingestion] File: Other_hyper_123.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_123.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_124.tif
#    [Ingestion] File: Other_hyper_124.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_124.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_125.tif
#    [Ingestion] File: Other_hyper_125.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_125.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_126.tif
#    [Ingestion] File: Other_hyper_126.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_126.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_127.tif
#    [Ingestion] File: Other_hyper_127.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_127.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_128.tif
#    [Ingestion] File: Other_hyper_128.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_128.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_129.tif
#    [Ingestion] File: Other_hyper_129.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_129.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_13.tif
#    [Ingestion] File: Other_hyper_13.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_13.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_130.tif
#    [Ingestion] File: Other_hyper_130.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_130.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_131.tif
#    [Ingestion] File: Other_hyper_131.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_131.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_132.tif
#    [Ingestion] File: Other_hyper_132.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_132.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_133.tif
#    [Ingestion] File: Other_hyper_133.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_133.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_134.tif
#    [Ingestion] File: Other_hyper_134.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_134.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_135.tif
#    [Ingestion] File: Other_hyper_135.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_135.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_136.tif
#    [Ingestion] File: Other_hyper_136.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_136.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_137.tif
#    [Ingestion] File: Other_hyper_137.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_137.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_138.tif
#    [Ingestion] File: Other_hyper_138.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_138.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_139.tif
#    [Ingestion] File: Other_hyper_139.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_139.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_14.tif
#    [Ingestion] File: Other_hyper_14.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_14.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_140.tif
#    [Ingestion] File: Other_hyper_140.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_140.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_141.tif
#    [Ingestion] File: Other_hyper_141.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_141.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_142.tif
#    [Ingestion] File: Other_hyper_142.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_142.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_143.tif
#    [Ingestion] File: Other_hyper_143.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_143.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_144.tif
#    [Ingestion] File: Other_hyper_144.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_144.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_145.tif
#    [Ingestion] File: Other_hyper_145.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_145.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_146.tif
#    [Ingestion] File: Other_hyper_146.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_146.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_147.tif
#    [Ingestion] File: Other_hyper_147.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_147.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_148.tif
#    [Ingestion] File: Other_hyper_148.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_148.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_149.tif
#    [Ingestion] File: Other_hyper_149.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_149.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_15.tif
#    [Ingestion] File: Other_hyper_15.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_15.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_150.tif
#    [Ingestion] File: Other_hyper_150.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_150.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_151.tif
#    [Ingestion] File: Other_hyper_151.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_151.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_152.tif
#    [Ingestion] File: Other_hyper_152.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_152.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_153.tif
#    [Ingestion] File: Other_hyper_153.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_153.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_154.tif
#    [Ingestion] File: Other_hyper_154.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_154.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_155.tif
#    [Ingestion] File: Other_hyper_155.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_155.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_156.tif
#    [Ingestion] File: Other_hyper_156.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_156.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_157.tif
#    [Ingestion] File: Other_hyper_157.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_157.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_158.tif
#    [Ingestion] File: Other_hyper_158.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_158.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_159.tif
#    [Ingestion] File: Other_hyper_159.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_159.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_16.tif
#    [Ingestion] File: Other_hyper_16.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_16.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_160.tif
#    [Ingestion] File: Other_hyper_160.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_160.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_161.tif
#    [Ingestion] File: Other_hyper_161.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_161.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_162.tif
#    [Ingestion] File: Other_hyper_162.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_162.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_163.tif
#    [Ingestion] File: Other_hyper_163.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_163.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_164.tif
#    [Ingestion] File: Other_hyper_164.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_164.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_165.tif
#    [Ingestion] File: Other_hyper_165.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_165.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_166.tif
#    [Ingestion] File: Other_hyper_166.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_166.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_167.tif
#    [Ingestion] File: Other_hyper_167.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_167.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_168.tif
#    [Ingestion] File: Other_hyper_168.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_168.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_169.tif
#    [Ingestion] File: Other_hyper_169.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_169.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_17.tif
#    [Ingestion] File: Other_hyper_17.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_17.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_170.tif
#    [Ingestion] File: Other_hyper_170.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_170.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_171.tif
#    [Ingestion] File: Other_hyper_171.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_171.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_172.tif
#    [Ingestion] File: Other_hyper_172.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_172.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_173.tif
#    [Ingestion] File: Other_hyper_173.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_173.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_174.tif
#    [Ingestion] File: Other_hyper_174.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_174.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_175.tif
#    [Ingestion] File: Other_hyper_175.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_175.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_176.tif
#    [Ingestion] File: Other_hyper_176.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_176.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_177.tif
#    [Ingestion] File: Other_hyper_177.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_177.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_178.tif
#    [Ingestion] File: Other_hyper_178.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_178.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_179.tif
#    [Ingestion] File: Other_hyper_179.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_179.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_18.tif
#    [Ingestion] File: Other_hyper_18.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_18.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_180.tif
#    [Ingestion] File: Other_hyper_180.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_180.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_181.tif
#    [Ingestion] File: Other_hyper_181.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_181.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_182.tif
#    [Ingestion] File: Other_hyper_182.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_182.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_183.tif
#    [Ingestion] File: Other_hyper_183.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_183.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_184.tif
#    [Ingestion] File: Other_hyper_184.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_184.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_185.tif
#    [Ingestion] File: Other_hyper_185.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_185.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_186.tif
#    [Ingestion] File: Other_hyper_186.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_186.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_187.tif
#    [Ingestion] File: Other_hyper_187.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_187.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_188.tif
#    [Ingestion] File: Other_hyper_188.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_188.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_189.tif
#    [Ingestion] File: Other_hyper_189.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_189.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_19.tif
#    [Ingestion] File: Other_hyper_19.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_19.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_190.tif
#    [Ingestion] File: Other_hyper_190.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_190.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_191.tif
#    [Ingestion] File: Other_hyper_191.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_191.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_192.tif
#    [Ingestion] File: Other_hyper_192.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_192.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_193.tif
#    [Ingestion] File: Other_hyper_193.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_193.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_194.tif
#    [Ingestion] File: Other_hyper_194.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_194.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_195.tif
#    [Ingestion] File: Other_hyper_195.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_195.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_196.tif
#    [Ingestion] File: Other_hyper_196.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_196.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_197.tif
#    [Ingestion] File: Other_hyper_197.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_197.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_198.tif
#    [Ingestion] File: Other_hyper_198.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_198.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_199.tif
#    [Ingestion] File: Other_hyper_199.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_199.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_2.tif
#    [Ingestion] File: Other_hyper_2.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_2.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_20.tif
#    [Ingestion] File: Other_hyper_20.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_20.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_200.tif
#    [Ingestion] File: Other_hyper_200.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_200.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_21.tif
#    [Ingestion] File: Other_hyper_21.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_21.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_22.tif
#    [Ingestion] File: Other_hyper_22.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_22.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_23.tif
#    [Ingestion] File: Other_hyper_23.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_23.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_24.tif
#    [Ingestion] File: Other_hyper_24.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_24.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_25.tif
#    [Ingestion] File: Other_hyper_25.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_25.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_26.tif
#    [Ingestion] File: Other_hyper_26.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_26.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_27.tif
#    [Ingestion] File: Other_hyper_27.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_27.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_28.tif
#    [Ingestion] File: Other_hyper_28.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_28.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_29.tif
#    [Ingestion] File: Other_hyper_29.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_29.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_3.tif
#    [Ingestion] File: Other_hyper_3.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_3.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_30.tif
#    [Ingestion] File: Other_hyper_30.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_30.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_31.tif
#    [Ingestion] File: Other_hyper_31.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_31.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_32.tif
#    [Ingestion] File: Other_hyper_32.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_32.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_33.tif
#    [Ingestion] File: Other_hyper_33.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_33.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_34.tif
#    [Ingestion] File: Other_hyper_34.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_34.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_35.tif
#    [Ingestion] File: Other_hyper_35.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_35.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_36.tif
#    [Ingestion] File: Other_hyper_36.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_36.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_37.tif
#    [Ingestion] File: Other_hyper_37.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_37.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_38.tif
#    [Ingestion] File: Other_hyper_38.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_38.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_39.tif
#    [Ingestion] File: Other_hyper_39.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_39.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_4.tif
#    [Ingestion] File: Other_hyper_4.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_4.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_40.tif
#    [Ingestion] File: Other_hyper_40.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_40.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_41.tif
#    [Ingestion] File: Other_hyper_41.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_41.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_42.tif
#    [Ingestion] File: Other_hyper_42.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_42.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_43.tif
#    [Ingestion] File: Other_hyper_43.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_43.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_44.tif
#    [Ingestion] File: Other_hyper_44.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_44.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_45.tif
#    [Ingestion] File: Other_hyper_45.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_45.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_46.tif
#    [Ingestion] File: Other_hyper_46.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_46.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_47.tif
#    [Ingestion] File: Other_hyper_47.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_47.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_48.tif
#    [Ingestion] File: Other_hyper_48.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_48.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_49.tif
#    [Ingestion] File: Other_hyper_49.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_49.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_5.tif
#    [Ingestion] File: Other_hyper_5.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_5.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_50.tif
#    [Ingestion] File: Other_hyper_50.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_50.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_51.tif
#    [Ingestion] File: Other_hyper_51.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_51.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_52.tif
#    [Ingestion] File: Other_hyper_52.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_52.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_53.tif
#    [Ingestion] File: Other_hyper_53.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_53.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_54.tif
#    [Ingestion] File: Other_hyper_54.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_54.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_55.tif
#    [Ingestion] File: Other_hyper_55.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_55.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_56.tif
#    [Ingestion] File: Other_hyper_56.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_56.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_57.tif
#    [Ingestion] File: Other_hyper_57.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_57.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_58.tif
#    [Ingestion] File: Other_hyper_58.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_58.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_59.tif
#    [Ingestion] File: Other_hyper_59.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_59.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_6.tif
#    [Ingestion] File: Other_hyper_6.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_6.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_60.tif
#    [Ingestion] File: Other_hyper_60.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_60.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_61.tif
#    [Ingestion] File: Other_hyper_61.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_61.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_62.tif
#    [Ingestion] File: Other_hyper_62.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_62.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_63.tif
#    [Ingestion] File: Other_hyper_63.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_63.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_64.tif
#    [Ingestion] File: Other_hyper_64.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_64.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_65.tif
#    [Ingestion] File: Other_hyper_65.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_65.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_66.tif
#    [Ingestion] File: Other_hyper_66.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_66.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_67.tif
#    [Ingestion] File: Other_hyper_67.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_67.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_68.tif
#    [Ingestion] File: Other_hyper_68.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_68.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_69.tif
#    [Ingestion] File: Other_hyper_69.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_69.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_7.tif
#    [Ingestion] File: Other_hyper_7.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_7.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_70.tif
#    [Ingestion] File: Other_hyper_70.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_70.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_71.tif
#    [Ingestion] File: Other_hyper_71.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_71.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_72.tif
#    [Ingestion] File: Other_hyper_72.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_72.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_73.tif
#    [Ingestion] File: Other_hyper_73.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_73.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_74.tif
#    [Ingestion] File: Other_hyper_74.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_74.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_75.tif
#    [Ingestion] File: Other_hyper_75.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_75.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_76.tif
#    [Ingestion] File: Other_hyper_76.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_76.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_77.tif
#    [Ingestion] File: Other_hyper_77.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_77.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_78.tif
#    [Ingestion] File: Other_hyper_78.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_78.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_79.tif
#    [Ingestion] File: Other_hyper_79.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_79.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_8.tif
#    [Ingestion] File: Other_hyper_8.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_8.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_80.tif
#    [Ingestion] File: Other_hyper_80.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_80.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_81.tif
#    [Ingestion] File: Other_hyper_81.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_81.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_82.tif
#    [Ingestion] File: Other_hyper_82.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_82.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_83.tif
#    [Ingestion] File: Other_hyper_83.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_83.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_84.tif
#    [Ingestion] File: Other_hyper_84.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_84.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_85.tif
#    [Ingestion] File: Other_hyper_85.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_85.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_86.tif
#    [Ingestion] File: Other_hyper_86.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_86.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_87.tif
#    [Ingestion] File: Other_hyper_87.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_87.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_88.tif
#    [Ingestion] File: Other_hyper_88.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_88.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_89.tif
#    [Ingestion] File: Other_hyper_89.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_89.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_9.tif
#    [Ingestion] File: Other_hyper_9.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_9.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_90.tif
#    [Ingestion] File: Other_hyper_90.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_90.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_91.tif
#    [Ingestion] File: Other_hyper_91.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_91.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_92.tif
#    [Ingestion] File: Other_hyper_92.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_92.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_93.tif
#    [Ingestion] File: Other_hyper_93.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_93.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_94.tif
#    [Ingestion] File: Other_hyper_94.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_94.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_95.tif
#    [Ingestion] File: Other_hyper_95.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_95.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_96.tif
#    [Ingestion] File: Other_hyper_96.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_96.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_97.tif
#    [Ingestion] File: Other_hyper_97.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_97.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_98.tif
#    [Ingestion] File: Other_hyper_98.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_98.tif
#    [Ingestion] Pattern Detection used: Spectral Date/Time Pattern detected for Other_hyper_99.tif
#    [Ingestion] File: Other_hyper_99.tif -> Detected Type: Unclassified, Plant: Other
# ⚠️ Skipped Unclassified file: Other_hyper_99.tif
#    -> 0 files successfully organized.
# Attempt to connect to MongoDB on localhost
# ✅ Connected to MongoDB on localhost
#
# --- 2. Scientific Processing ---
# 📄 [Manifest] FirstTests.txt Loaded metadata -> SN: CMS25030452, Exp: 7.78ms
# 📄 [Manifest] PO1.txt Loaded metadata -> SN: CMS25030452, Exp: 8.33ms
# 📄 [Manifest] test.txt Loaded metadata -> SN: CMS25030452, Exp: 8.33ms
# 📄 [Manifest] TEST2.txt Loaded metadata -> SN: CMS25030452, Exp: 8.33ms
#
# --- 3. Independent Thermal Scan ---
#
# 🔄 [Independent Thermal] Scanning for standalone thermal data in 2025-12-10...
#    -> Added 0 new independent thermal events.
#
# 🔄 [Independent Thermal] Scanning for standalone thermal data in 2026-03-18...
#    -> Added 0 new independent thermal events.
#
# ✅ Pipeline execution complete.

# %%
# To get the Spectral Image

# export_file_from_db("./EXPORTS", plant_id="P01", sensor_type="spectral")


# To get the Thermal Radiometric Image (for reports)

# export_file_from_db("./EXPORTS", plant_id="P01", sensor_type="thermal", thermal_file_type="radiometric_jpg")


# To get the Raw Thermal Data (for analysis):

# export_file_from_db("./EXPORTS", plant_id="P01", sensor_type="thermal", thermal_file_type="raw_thermal_tiff")

# %%
# To clean everything on the database
# ⚠️ IT WILL DELETE EVERYTHING ON MONGODB⚠️

#client = MongoClient('localhost', 27017)
#client['cropsense_db']['capture_events'].drop()
#print("Base de données nettoyée !")

# %%
# To export all the data from the database to your pc
#batch_export_all()

# %%
# To rename your files from a prefix to an other prefix
rename_batch_prefix(PATH_INBOX, "Health_hyper", "Spectral_health")
# Out:
# 🔄 Renaming in progress in C:/CROPSENSE/INBOX...
#    Replacing 'Health_hyper' with 'Spectral_health'
#
# --- Finished: 0 files renamed (0 errors) ---

# %%
#check_database_integrity("FirstTests", mongo_uri="localhost")

# %%
# Example 1: Show band by Index (0 = 410nm)
show_spectral_channel("C:/CROPSENSE/CROPSENSE_DATA/2026-03-18/rust/Spectral/Spectral_rust_4.tif", channel_index=5)
show_spectral_channel("C:/CROPSENSE/CROPSENSE_DATA/2026-03-18/rust/Spectral/Spectral_rust_4.tif", wavelength=740)

# Example 2: Show band by Wavelength (e.g., Red Edge 756nm)
show_spectral_channel("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", wavelength=756)
# Out:
# 🔍 Wavelength 740.0nm correspond to channel index 72

# %%
# --- EXAMPLE: Plot a thermic image file ---
# This will show the temperature and the water stress.
show_thermal_image("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/PreSample/Thermal/Thermal_PreSample_00-08-09-074-thermo.tiff")
show_thermal_image("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/PreSample/Thermal/Thermal_PreSample_00-08-09-074-cwsi.tiff")
# Out:
# 📊 Statistics for thermal_presample_00-08-09-074-thermo.tiff:
#    🔹 Min: 19451.00
#    🔸 Max: 26366.00
#    sz Mean: 22738.63
# 📊 Statistics for thermal_presample_00-08-09-074-cwsi.tiff:
#    🔹 Min: 1904.00
#    🔸 Max: 5070.00
#    sz Mean: 3409.06

# %%
# --- EXAMPLE 1: Check the "Red Edge" band (Index 7) of a multispectral file ---
# This helps you see if the specific band used for NDVI is well exposed.
spectral_file = "C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff"
plot_image_histogram(spectral_file, band_index=7, bins=100, log_scale=True)

# --- EXAMPLE 2: Check a Thermal Temperature Map ---
# This shows the distribution of temperatures (e.g., most pixels are around 22°C).
thermal_file = "C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/PreSample/Thermal/Thermal_PreSample_00-08-09-074-thermo.tiff"
plot_image_histogram(thermal_file, bins=50, log_scale=True)

# %% [markdown]
# O

# %%
# --- EXAMPLE 1: Overlay Mode (Recommended) ---
# Draws 10 colored lines. Perfect to see if ONE specific band is dead or saturated.
plot_full_spectral_histogram("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", mode='overlay', log_scale=True)

# --- EXAMPLE 2: Global Mode ---
# Aggregates everything. Good to see the overall brightness of the image.
plot_full_spectral_histogram("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", mode='global', log_scale=True)
# Out:
# 📊 Plotting Global Raw Histogram.
# 📊 Plotting Global Raw Histogram.

# %%
plot_spectral_profile("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", smooth=False)

# %%
# --- EXAMPLE: Export data to a CSV file ---
# This will create a file named 'Analysis_P01.csv' in your current folder.
# You can then open this file in Excel to make your own custom graphs.
df = export_histogram_to_csv("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", output_csv="Analysis_P01_histogram.csv", analysis_type=histogram)


df = export_histogram_to_csv("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", output_csv="Analysis_P01_profile.csv", analysis_type=profile)
# Optional: Print the first few rows to verify
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 # --- EXAMPLE: Export data to a CSV file ---
#       2 # This will create a file named 'Analysis_P01.csv' in your current folder.
#       3 # You can then open this file in Excel to make your own custom graphs.
# ----> 4 df = export_histogram_to_csv("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", output_csv="Analysis_P01_histogram.csv", analysis_type=histogram)
#       7 df = export_histogram_to_csv("C:/CROPSENSE/CROPSENSE_DATA/2025-12-10/test/Spectral/test_20251201_153000_830_00000000_raw.tiff", output_csv="Analysis_P01_profile.csv", analysis_type=profile)
#       8 # Optional: Print the first few rows to verify
#
# NameError: name 'export_histogram_to_csv' is not defined
